# %% [markdown]
# # Lets df and viz your sql data

# %%
# Import numpy, pandas and pymysql sqlalchemy (following what you have learned in previous lessons):

import pymysql 
from sqlalchemy import create_engine 
import pandas as pd

# %%
import getpass

# %%
mysqlpassword= getpass.getpass()
# Out:
# ········

# %% [markdown]
# # Challenge 1 - Load and Evaluate the Datasets
#
# #### In this challenge we will load data from MySQL Sakila database or MySQL bank database (or any other DB); by querying and evaluating the results returned using MySQL we can be selective about the data used to make visualisation with seaborn/matplotlib very easy. Ideally you want to bring some data from SQL into python which will allow you to plot a trend or comparison.
#
# In the cell below, create a mysql engine for your local mysql instance and include your username, password and database schema name by creating a variable connection string following the following pattern:
#
# create_engine(‘dialect+driver://username:password@host:port/database’)
#
# This is the format to create the connection string and engine for a local mysql connection
#
# > connection_string = 'mysql+pymysql://root:' + 'password' + '@localhost/DB'
#
# - replace root with your username and password with your password
# - replace DB with database name
#
# > engine = create_engine(connection_string)

# %%
connection_string = 'mysql+pymysql://root:' + mysqlpassword + '@localhost/sakila'
engine= create_engine(connection_string)

# %%
# Your code here:
# dataframe creation 
df= pd.read_sql_query('Select * from rental', engine)

# %%
df
# Out:
#        rental_id         rental_date  inventory_id  customer_id  \
# 0              1 2005-05-24 22:53:30           367          130
# 1              2 2005-05-24 22:54:33          1525          459
# 2              3 2005-05-24 23:03:39          1711          408
# 3              4 2005-05-24 23:04:41          2452          333
# 4              5 2005-05-24 23:05:21          2079          222
# ...          ...                 ...           ...          ...
# 16039      16045 2005-08-23 22:25:26           772           14
# 16040      16046 2005-08-23 22:26:47          4364           74
# 16041      16047 2005-08-23 22:42:48          2088          114
# 16042      16048 2005-08-23 22:43:07          2019          103
# 16043      16049 2005-08-23 22:50:12          2666          393
#
#               return_date  staff_id         last_update
# 0     2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1     2005-05-28 19:40:33         1 2006-02-15 21:30:53
# 2     2005-06-01 22:12:39         1 2006-02-15 21:30:53
# 3     2005-06-03 01:43:41         2 2006-02-15 21:30:53
# 4     2005-06-02 04:33:21         1 2006-02-15 21:30:53
# ...                   ...       ...                 ...
# 16039 2005-08-25 23:54:26         1 2006-02-15 21:30:53
# 16040 2005-08-27 18:02:47         2 2006-02-15 21:30:53
# 16041 2005-08-25 02:48:48         2 2006-02-15 21:30:53
# 16042 2005-08-31 21:33:07         1 2006-02-15 21:30:53
# 16043 2005-08-30 01:01:12         2 2006-02-15 21:30:53
#
# [16044 rows x 7 columns]

# %% [markdown]
# Use this connection to load data with a sql query which connects the target tables in your database using joins, selects the fields you wish to work with and any aggregation columns + grouping / window function new columns or filters by where/having as appropriate. You can draw on any of the labs or lessons to establish what your query should look like. Its ok if this stage is a little trial and error but I recommend testing the query in your MySql client to ensure it returns the results you want!

# %%
# Your code here:
lreturn=pd.read_sql_query('''SELECT film_id, release_year, language_id, rental_rate, length, replacement_cost, rating, case 
when rental_duration > 3 then "Late"
else "On-time"
end as late_return, 
case 
when rental_duration > 3 then 1
else 0
end as late_return_bool
 FROM sakila.film;''',engine)

# %%
lreturn.head()
# Out:
#    film_id  release_year  language_id  rental_rate  length  replacement_cost  \
# 0        1          2006            1         0.99      86             20.99
# 1        2          2006            1         4.99      48             12.99
# 2        3          2006            1         2.99      50             18.99
# 3        4          2006            1         2.99     117             26.99
# 4        5          2006            1         2.99     130             22.99
#
#   rating late_return  late_return_bool
# 0     PG        Late                 1
# 1      G     On-time                 0
# 2  NC-17        Late                 1
# 3      G        Late                 1
# 4      G        Late                 1

# %%
### creates a boolean value from rental duration > 3 days = late return

# %%
lreturn.head()
# Out:
#    film_id  release_year  language_id  rental_rate  length  replacement_cost  \
# 0        1          2006            1         0.99      86             20.99
# 1        2          2006            1         4.99      48             12.99
# 2        3          2006            1         2.99      50             18.99
# 3        4          2006            1         2.99     117             26.99
# 4        5          2006            1         2.99     130             22.99
#
#   rating late_return  late_return_bool
# 0     PG        late                 1
# 1      G     on-time                 0
# 2  NC-17        late                 1
# 3      G        late                 1
# 4      G        late                 1

# %%
lreturn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   release_year      1000 non-null   int64
#  2   language_id       1000 non-null   int64
#  3   rental_rate       1000 non-null   float64
#  4   length            1000 non-null   int64
#  5   replacement_cost  1000 non-null   float64
#  6   rating            1000 non-null   object
#  7   late_return       1000 non-null   object
#  8   late_return_bool  1000 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 70.4+ KB

# %% [markdown]
# once you have your sql query worked out, make sure you turn your query response into a pandas dataframe in the format
#
# > df = pd.read_sql_query(query, engine)

# %%
# Your code here:

# %% [markdown]
# #### Let's start examining the dataset to ensure we have the data we want to visualise.
#
# First look at the first five rows using the `head` function.

# %%
# Your code here:

lreturn.head()
# Out:
#    film_id  release_year  language_id  rental_rate  length  replacement_cost  \
# 0        1          2006            1         0.99      86             20.99
# 1        2          2006            1         4.99      48             12.99
# 2        3          2006            1         2.99      50             18.99
# 3        4          2006            1         2.99     117             26.99
# 4        5          2006            1         2.99     130             22.99
#
#   rating late_return  late_return_bool
# 0     PG        late                 1
# 1      G     on-time                 0
# 2  NC-17        late                 1
# 3      G        late                 1
# 4      G        late                 1

# %% [markdown]
# Next, lets use the `info` function to see the dtypes and row counts

# %%
# Your code here:
lreturn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   release_year      1000 non-null   int64
#  2   language_id       1000 non-null   int64
#  3   rental_rate       1000 non-null   float64
#  4   length            1000 non-null   int64
#  5   replacement_cost  1000 non-null   float64
#  6   rating            1000 non-null   object
#  7   late_return       1000 non-null   object
#  8   late_return_bool  1000 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 70.4+ KB

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Next, we'll examine the `describe` function to see the descriptive statistics for the numeric variables.

# %%
# Set the palette using the name of a palette:
sns.set_palette("viridis")

# %%
# Your code here:
plotdata= lreturn
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
lreturn.corr()
# Out:
#                    film_id  release_year  language_id  rental_rate    length  \
# film_id           1.000000           NaN          NaN    -0.012797  0.049141
# release_year           NaN           NaN          NaN          NaN       NaN
# language_id            NaN           NaN          NaN          NaN       NaN
# rental_rate      -0.012797           NaN          NaN     1.000000  0.029789
# length            0.049141           NaN          NaN     0.029789  1.000000
# replacement_cost -0.049518           NaN          NaN    -0.044620  0.005605
# late_return_bool -0.051014           NaN          NaN     0.045279  0.029485
#
#                   replacement_cost  late_return_bool
# film_id                  -0.049518         -0.051014
# release_year                   NaN               NaN
# language_id                    NaN               NaN
# rental_rate              -0.044620          0.045279
# length                    0.005605          0.029485
# replacement_cost          1.000000         -0.001323
# late_return_bool         -0.001323          1.000000

# %% [markdown]
# #### At this stage it may be necessary to load another set of data with an additional mysql query and repeat the stages above - perhaps you are thinking to join the results of your two queries together or you think that both should be visualised separately to answer the question you came up with?
#
# Do this in the following 3 cells below.

# %%
#create a sub data frame of the numeric variables you want to analyse next to eachother
lreturnnum=lreturn._get_numeric_data()
lreturn.head()
# Out:
#    film_id  release_year  language_id  rental_rate  length  replacement_cost  \
# 0        1          2006            1         0.99      86             20.99
# 1        2          2006            1         4.99      48             12.99
# 2        3          2006            1         2.99      50             18.99
# 3        4          2006            1         2.99     117             26.99
# 4        5          2006            1         2.99     130             22.99
#
#   rating late_return  late_return_bool
# 0     PG        late                 1
# 1      G     on-time                 0
# 2  NC-17        late                 1
# 3      G        late                 1
# 4      G        late                 1

# %%
# Your code here:
#all histograms 
lreturnnum.hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
#standard box plot 
sns.boxplot(x='rating', y='replacement_cost', hue ='late_return', data=lreturn)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='replacement_cost'>

# %%
#standard box plot 
sns.boxplot(x='rating', y='replacement_cost', hue ='rating', data=lreturn)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='replacement_cost'>

# %%
# Your code here (box plot to see outliers for specific columns)
# all scatter plots as a matrix
sns.pairplot(lreturnnum)

# %%
corr_data = lreturnnum.drop(['film_id'], axis=1)
correlations_matrix = corr_data.corr()
correlations_matrix
# Out:
#                   release_year  language_id  rental_rate    length  \
# release_year               NaN          NaN          NaN       NaN
# language_id                NaN          NaN          NaN       NaN
# rental_rate                NaN          NaN     1.000000  0.029789
# length                     NaN          NaN     0.029789  1.000000
# replacement_cost           NaN          NaN    -0.044620  0.005605
# late_return_bool           NaN          NaN     0.045279  0.029485
#
#                   replacement_cost  late_return_bool
# release_year                   NaN               NaN
# language_id                    NaN               NaN
# rental_rate              -0.044620          0.045279
# length                    0.005605          0.029485
# replacement_cost          1.000000         -0.001323
# late_return_bool         -0.001323          1.000000

# %%
#create a heatmap  
sns.heatmap(correlations_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Optional - if you are using more than one sql query
#
# If you decided to load two dataframes from two separate mysql queries and need to merge them using the merge concat or join functions, do so now. You can follow [this tutorial](https://realpython.com/pandas-merge-join-and-concat/) for more information about bringing dataframes together

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Export your data frame as a csv
#
# Export df to a csv file using the `df.to_csv` function, filtered if suitable, excluding any columns which are not useful for further analysis

# %%
# Your code here:
df.to_csv

# %% [markdown]
# # Challenge 3: Visualise relationships or trends found in the data
#
# At this stage you can visualise the data in your chosen tool, Tableau, Excel, Python(matploitlib,seaborn)
#
# **Business Question**: think about what are the question(s) you want to answer with the data you have gathered from the MySQL database. Make the question as specific as possible
# - for example, are childrens films rented more frequently on weekends than comedies?
#
# **Visuals**: Think about what plot type best supports answering your question(s). Each plot/ visualisation should have an appropriate title, legend and axis labels, so the meaning is as clear as possible without needing a caption. Make use of colour pallettes ! dont just create a blue plot :)

# %%
# (if plotting in python) Your code here: 
sns.set_style('whitegrid') #set theme
#Create subplot
fig,ax = plt.subplots(figsize=(16,10))
#Plot the swarm
chart = sns.swarmplot(x="rating", y="replacement_cost", data=lreturn)
#Label
chart5.set_ylabel('Cost',weight='bold',fontsize=13)
chart5.set_xlabel('Rating', weight='bold',fontsize=13)
chart5.set_title('Replacement cost',weight='bold',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Replacement cost')

# %%
#Horizontal barchart
#Create subplot
sns.set_style('whitegrid') #set theme
fig,ax=plt.subplots(figsize=(16,7))
#Create barplot
chart2 = sns.barplot(x="replacement_cost",y="rating", data=lreturn)
#Customize chart
chart2.set_xlabel('Total replacement costs',weight='bold',fontsize=13)
chart2.set_ylabel('Ratings', weight='bold',fontsize=13)
chart2.set_title('Replacement costs by rating',weight='bold',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Replacement costs by rating')

# %%
connection_string = 'mysql+pymysql://root:' + mysqlpassword + '@localhost/bank'
engine= create_engine(connection_string)

# %%
statuses=pd.read_sql_query('''select l.status, t.date,
count(distinct t.account_id) as noofaccounts,
count(distinct t.trans_id) as nooftrans,
sum(t.amount) as movedamount 
from trans t
join disp d using (account_id) 
join loan l using (account_id) 
where d.type = 'OWNER'
group by l.status, t.date''',engine)

# %%
statuses.head(20)
# Out:
#    status    date  noofaccounts  nooftrans   movedamount   M-Y
# 0       A  930114             2          2  45749.000000  9301
# 1       A  930117             1          1   1100.000000  9301
# 2       A  930119             1          1    700.000000  9301
# 3       A  930124             1          1    900.000000  9301
# 4       A  930125             1          1    900.000000  9301
# 5       A  930130             1          1   1000.000000  9301
# 6       A  930131             2          3   5392.999997  9301
# 7       A  930204             1          1    300.000000  9302
# 8       A  930205             1          1   7618.000000  9302
# 9       A  930207             2          2  14693.000000  9302
# 10      A  930208             3          3   2100.000000  9302
# 11      A  930210             1          1   1100.000000  9302
# 12      A  930211             1          1  12154.000000  9302
# 13      A  930212             3          4  93135.000000  9302
# 14      A  930213             2          2  10500.000000  9302
# 15      A  930214             1          1  44749.000000  9302
# 16      A  930216             1          1   4200.000000  9302
# 17      A  930218             2          2  30623.000000  9302
# 18      A  930219             1          1  33410.000000  9302
# 19      A  930220             1          1    700.000000  9302

# %%
statuses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7615 entries, 0 to 7614
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        7615 non-null   object
#  1   date          7615 non-null   int64
#  2   noofaccounts  7615 non-null   int64
#  3   nooftrans     7615 non-null   int64
#  4   movedamount   7615 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 297.6+ KB

# %%
b_status = statuses.query("status == 'A'")
fig = plt.figure(figsize=(16,8))
sns.lineplot(data=b_status, x="M-Y", y="movedamount", ci=None)
# Out:
# <AxesSubplot:xlabel='M-Y', ylabel='movedamount'>

# %%
#extract month and year from date field (first four characters :4)
statuses['date'] = statuses['date'].astype(str)
statuses['M-Y'] = statuses[str('date')].str[:4]

# %%
b_status = statuses.query("status == 'B'")
fig = plt.figure(figsize=(16,8))
sns.lineplot(data=b_status, x="M-Y", y="movedamount", ci=None)
# Out:
# <AxesSubplot:xlabel='M-Y', ylabel='movedamount'>

# %%
#group the loan statuses - create function
def statusgroup(x):
    if x in ['B', 'D']:
        return 'badloans'
    else:
        return 'goodloans'

# %%
#apply this to a new column using list map
statuses['statusgroup']= list(map(statusgroup, statuses['status']))

# %%
#create a group by df
grouped=statuses.groupby(["M-Y", "statusgroup"])["nooftrans"].sum()
grouped.head()
# Out:
# M-Y   statusgroup
# 9301  badloans        3
#       goodloans      10
# 9302  badloans        3
#       goodloans      42
# 9303  badloans       13
# Name: nooftrans, dtype: int64

# %%
fig = plt.figure(figsize=(16,8))
g=sns.lineplot(data=statuses, x="M-Y", y="nooftrans", hue="statusgroup", ci= None)
g.set(xticklabels=[])
g.set(xlabel='Month and year')
g.set(title='account activity over time associated with good or bad loans')
g.tick_params(bottom=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Export the merged data set to csv - 
# potentially filtered to a subset of rows by date 
# or a subset of useful columns.
lreturn.to_csv("late_returns_sakila.csv")

# %%
# Summarise and visualise your insight in the data. You can visualise this inside Python 
# using one of the visualisation libraries
sns.jointplot("replacement_cost", "rental_rate", data=lreturn, kind='reg');
# Out:
# /Users/nayo/opt/anaconda3/envs/Ironhack/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# The data is quite ugly for visualizations :-/
